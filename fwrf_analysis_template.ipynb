# %%
import sys
import os
import struct
import time
import numpy as np
import h5py
from glob import glob
import nibabel as nib
import scipy.io as sio
from scipy import ndimage as nd
from scipy.io import loadmat
from scipy import misc
from tqdm import tqdm
import pickle
import math
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm 
import seaborn as sns
import PIL.Image as pim
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

import src.numpy_utility as pnu
import src.fwrf as prf
from src.fwrf import fpX
from src.plots import plot_pretty_scatter, plot_rf_as_circles

# %%
timestamp = time.strftime('%b-%d-%Y_%H%M', time.localtime())

root_dir   = os.getcwd() + '/'
input_dir  = root_dir+"output/"
output_dir = root_dir+"results_redone/"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

print "Time Stamp: %s" % timestamp
# Out:
# Time Stamp: Sep-21-2017_1338

# %%
saveext = ".pdf"
savearg = {'format': 'pdf', 'dpi': 200}

# %% [markdown]
# # 1) Preliminary setup
# ## Choose the plotting style

# %%
sns.axes_style()
#sns.plotting_context()
print sns.color_palette("hls")
# Out:
# [(0.86, 0.37119999999999997, 0.33999999999999997), (0.82879999999999987, 0.86, 0.33999999999999997), (0.33999999999999997, 0.86, 0.37119999999999997), (0.33999999999999997, 0.82879999999999987, 0.86), (0.37119999999999997, 0.33999999999999997, 0.86), (0.86, 0.33999999999999997, 0.82879999999999987)]

# %%
sns.set_style("whitegrid", {"axes.facecolor": '.95'})
sns.set_context("notebook", rc={'axes.labelsize': 18.0, 'axes.titlesize': 24.0, 'legend.fontsize': 18.0, 'xtick.labelsize': 18.0, 'ytick.labelsize': 18.0})
sns.set_palette("deep")

# %% [markdown]
# ## Load the voxel masks

# %%
dataset_dir = "/home/styvesg/Documents/PostDoc/Datasets/vim-1/"

voxelset = h5py.File(dataset_dir+"EstimatedResponses.mat")
print voxelset.keys()
# Out:
# [u'dataTrnS1', u'dataTrnS2', u'dataValS1', u'dataValS2', u'roiS1', u'roiS2', u'voxIdxS1', u'voxIdxS2']

# %%
subject = 'S1'

trn_size = 1750
val_size = 120

roi_names = ['other', 'V1', 'V2', 'V3', 'V3a', 'V3b', 'V4', 'LO']
roi_markers = ['o', 's', '^', 'D', 'v', '<', '>', '*', 'x']
roi_all = [[0, 1, 2, 3, 4, 5, 6, 7]]
roi_separated = [[0], [1], [2], [3], [4], [5], [6], [7]]
roi_lowhigh = [[1, 2, 3], [4, 5, 6, 7, 0]]
roi_v3together = [[1], [2], [3, 4, 5], [6], [7]]
roi_main = [[1], [2], [3], [6], [7]]
roi_dorsal  = [[1], [3], [4], [5]]
roi_ventral = [[1], [2], [6], [7]]
roi_vendrodorsal = [[7], [6], [2], [1], [3], [4], [5], [0]]

def iterate_roi(group, voxelroi, names):
    for g in group:
        g_name = ''
        mask = np.zeros(shape=voxelroi.shape, dtype=bool)
        for i,roi in enumerate(g):
            g_name += names[roi] + ('-' if i+1<len(g) else '')
            mask = np.logical_or(mask, voxelroi==roi)
        yield mask, g_name

# %%
voxeldata = np.concatenate([voxelset['dataTrn%s'%subject], voxelset['dataVal%s'%subject]], axis=0).astype(dtype=fpX)
voxelroi = voxelset['roi%s'%subject]
voxelidx = voxelset['voxIdx%s'%subject]
print voxeldata.shape


# purge all voxel that have no variance in the validation set

voxelNanMask = ~np.isnan(voxeldata).any(axis=0)
nv = np.sum(voxelNanMask)
print "%d voxels contain valid values for all images" % nv
# Out:
# (1870, 25915)
# 22701 voxels contain valid values for all images

# %%
voxelData = voxeldata[:, voxelNanMask].astype(dtype=fpX)
voxelROI  = voxelroi[:, voxelNanMask]
voxelIDX  = voxelidx[:, voxelNanMask]
print voxelData.shape

trnVoxelData = voxelData[:trn_size]
valVoxelData = voxelData[trn_size:]
# Out:
# (1870, 22701)

# %% [markdown]
# # Load the anatomical mask (we don't need it here)

# %%
def load_mask_from_nii(mask_nii_file):
    return nib.load(mask_nii_file).get_data()
    
def view_data(vol_shape, idx_mask, data_vol, save_to=None):
    view_vol = np.ones(np.prod(vol_shape), dtype=np.float32) * -1
    view_vol[idx_mask.astype('int').flatten()] = data_vol
    view_vol = view_vol.reshape(vol_shape, order='F')
    if save_to:
        nib.save(nib.Nifti1Image(view_vol, affine=np.eye(4)), save_to)
    return view_vol

# %%
anatomical_mask = load_mask_from_nii(dataset_dir+"Sub1_Anat_msk.nii.gz")

# %% [markdown]
# # 2a) LOAD THE RESULTS FOR MODEL 1

# %%
#m1_file_name = 'fwrf_gabor_S1_Mar-24-2017_1455_data'
#m1_part_name = 'fwrf_gabor_S1_Mar-24-2017_1455_part'

m1_file_name = 'fwrf_gabor_S1_Sep-19-2017_1214_residual'

#m1_file_name = 'fwrf_deepnet_S2_May-06-2017_1225_data'
#m1_part_name = 'fwrf_deepnet_S2_May-06-2017_1225_part'

# nx=15, ns=8
#m1_file_name = 'fwrf_deepnet_S1_Mar-25-2017_1549_data' 
#m1_part_name = 'fwrf_deepnet_S1_Mar-25-2017_1549_part' 

# nx=10, ns=6
#m1_file_name = 'fwrf_deepnet_S1_Mar-21-2017_1717_data' 
#m1_part_name = 'fwrf_deepnet_S1_Mar-21-2017_1717_part' 

# nx=6, ns=6
#m1_file_name = 'fwrf_deepnet_S1_Apr-26-2017_1057_data'

data_file = open(input_dir + "%s.pkl" % m1_file_name, 'rb')
#part_file = open(input_dir + "%s.pkl" % m1_part_name, 'rb')
m1_data_dict = pickle.load(data_file)
#m1_part_dict = pickle.load(part_file)
data_file.close()
#part_file.close()
print m1_data_dict.keys()
#print m1_part_dict.keys()

m1_name = m1_data_dict['model_name']
print m1_name
# Out:
# ['rf_params', 'fmaps_res_count', 'w_params', 'normstd', 'fmaps_count', 'voxel_idx', 'subject', 'dataset', 'project', 'normavg', 'grid', 'val_pred', 'gabor_params', 'scores', 'model_name', 'val_cc', 'voxel_roi', 'fmaps_sizes']
# gabor

# %%
print m1_data_dict['w_params'][0].shape
# Out:
# (22701, 48)

# %%
print m1_data_dict['grid'][0].shape + m1_data_dict['grid'][1].shape + m1_data_dict['grid'][2].shape

print "ranges:"
print m1_data_dict['grid'][0]
print m1_data_dict['grid'][2]
# Out:
# (26, 26, 12)
# ranges:
# [-9.61538506 -8.84615421 -8.07692337 -7.30769253 -6.53846169 -5.76923084
#  -5.         -4.23076916 -3.46153855 -2.69230771 -1.92307687 -1.15384614
#  -0.38461539  0.38461539  1.15384614  1.92307687  2.69230771  3.46153855
#   4.23076916  5.          5.76923084  6.53846169  7.30769253  8.07692337
#   8.84615421  9.61538506]
# [ 0.5         0.64333242  0.82775331  1.06504107  1.37035096  1.76318252
#   2.26862502  2.91896009  3.75572371  4.83235788  6.21762514  8.        ]

# %%
cc_th = 0.27

print "max cc = %f" % np.max(m1_data_dict['val_cc'])
print "sum(cc>0.2) = %d" % np.sum(map(lambda x: x > cc_th, m1_data_dict['val_cc']))

plt.figure(figsize=(15,5))
m1_bins=plt.hist(m1_data_dict['val_cc'], bins=100, range=(-.5, 1.))
plt.yscale('log')
plt.ylim([10**-1, 10**3])
plt.xlim([-.4, 0.9])
# Out:
# max cc = 0.568488
# sum(cc>0.2) = 229
# (-0.4, 0.9)

# %%
roi_volume = view_data((64, 64, 18), voxelIDX, voxelROI)
cc_volume = view_data((64, 64, 18), voxelIDX, m1_data_dict['val_cc'], save_to=output_dir+m1_file_name + '.nii')

# %%
fig = plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.imshow(roi_volume[:,:,10], cmap='Set1_r', interpolation='None')
plt.colorbar()
plt.subplot(1,2,2)
plt.imshow(cc_volume[:,:,10], cmap='inferno', interpolation='None')
plt.clim([0.,0.6])
plt.colorbar()

# %% [markdown]
# # 2b) LOAD THE RESULTS FOR MODEL 2

# %%
#m2_file_name = 'fwrf_deepnet_S1_Mar-26-2017_2035_layerwise_data'
#m2_part_name = 'fwrf_deepnet_S1_Mar-26-2017_2035_layerwise_part'

m2_file_name = 'fwrf_gabor_S2_Mar-22-2017_1625_data'
m2_part_name = 'fwrf_gabor_S2_Mar-22-2017_1625_part'

#m2_file_name = 'fwrf_gabor_S1_Mar-24-2017_1455_data'
#m2_part_name = 'fwrf_gabor_S1_Mar-24-2017_1455_part'

# nx=6, ns=6
#m2_file_name = 'fwrf_deepnet_S1_Apr-27-2017_1601_data'

data_file = open(input_dir + "%s.pkl" % m2_file_name, 'rb')
part_file = open(input_dir + "%s.pkl" % m2_part_name, 'rb')
m2_data_dict = pickle.load(data_file)
m2_part_dict = pickle.load(part_file)
data_file.close()
part_file.close()
print m2_data_dict.keys()
print m2_part_dict.keys()

m2_name = m2_data_dict['model_name']
print m2_name
# Out:
# ['fmaps_res_count', 'models', 'fmaps_count', 'dataset', 'grid', 'val_pred', 'scores', 'params', 'subject', 'val_cc', 'model_name', 'fmaps_sizes']
# ['val_ri', 'dataset', 'val_pred', 'val_cc', 'model_name', 'subject']
# gabor

# %%
print m2_data_dict['grid'][0].shape + m2_data_dict['grid'][1].shape + m2_data_dict['grid'][2].shape

print "ranges:"
print m2_data_dict['grid'][0]
print m2_data_dict['grid'][2]
# Out:
# (26, 26, 12)
# ranges:
# [-9.61538506 -8.84615421 -8.07692337 -7.30769253 -6.53846169 -5.76923084
#  -5.         -4.23076916 -3.46153855 -2.69230771 -1.92307687 -1.15384614
#  -0.38461539  0.38461539  1.15384614  1.92307687  2.69230771  3.46153855
#   4.23076916  5.          5.76923084  6.53846169  7.30769253  8.07692337
#   8.84615421  9.61538506]
# [ 0.5         0.64333242  0.82775331  1.06504107  1.37035096  1.76318252
#   2.26862502  2.91896009  3.75572371  4.83235788  6.21762514  8.        ]

# %%
cc_th = 0.27

print "max cc = %f" % np.max(m2_data_dict['val_cc'])
print "sum(cc>0.2) = %d" % np.sum(map(lambda x: x > cc_th, m2_data_dict['val_cc']))

plt.figure(figsize=(15,5))
m2_bins=plt.hist(m2_data_dict['val_cc'], bins=100, range=(-.5, 1.))
plt.yscale('log')
plt.ylim([10**-1, 10**3])
plt.xlim([-.4, 0.9])
# Out:
# max cc = 0.804318
# sum(cc>0.2) = 1021
# (-0.4, 0.9)

# %%
roi_volume = view_data((64, 64, 18), voxelIDX, voxelROI)
cc_volume = view_data((64, 64, 18), voxelIDX, m1_data_dict['val_cc'] - m2_data_dict['val_cc'], save_to=output_dir+m2_file_name + '__'+m1_file_name + '.diff.nii')

# %%
fig = plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.imshow(roi_volume[:,:,10], cmap='Set1_r', interpolation='None')
plt.colorbar()
plt.subplot(1,2,2)
plt.imshow(cc_volume[:,:,10], cmap='inferno', interpolation='None')
plt.clim([0.,0.4])
plt.colorbar()

# %% [markdown]
# # Compare the prediction accuracy of the 2 models

# %%
m1_cumsum = np.ndarray(shape=m1_bins[0].shape)
for i in range(len(m1_bins[0])):
    m1_cumsum[i] = np.sum(m1_bins[0][i:])
    
m1_gt02 = np.sum(map(lambda x: x > cc_th, m1_data_dict['val_cc'])) 

m2_cumsum = np.ndarray(shape=m2_bins[0].shape)
for i in range(len(m2_bins[0])):
    m2_cumsum[i] = np.sum(m2_bins[0][i:])
    
m2_gt02 = np.sum(map(lambda x: x > cc_th, m2_data_dict['val_cc']))

# %%
plt.plot(m1_bins[1][:-1], m1_cumsum, lw=4, label=m1_name)
plt.plot(m2_bins[1][:-1], m2_cumsum, lw=4, label=m2_name)

plt.plot([cc_th], [m1_gt02], linestyle='None', marker='o', markersize=15)
plt.text(cc_th+0.05, m1_gt02*1.08, '%d' % m1_gt02, fontsize=20)

plt.plot([cc_th], [m2_gt02], linestyle='None', marker='o', markersize=15)
plt.text(cc_th+0.05, m2_gt02*0.92, '%d' % m2_gt02, fontsize=20)
#plt.yscale('log')
plt.xlim([0, 1])
plt.ylim([0, 4000])
plt.xlabel(r'$\rho_t$')
plt.ylabel(r'Cumulative sum of voxel with $\rho>\rho_t$')
plt.legend()

# %%
m1_cc = m1_data_dict['val_cc']
m2_cc = m2_data_dict['val_cc']
m2_name = 'Gabor-fwRF'
m1_name = 'Deepnet-fwRF'
#rg = roi_all
rg = roi_lowhigh
#rg = roi_separated
for roi, value  in enumerate(iterate_roi(rg, voxelROI.flatten(), roi_names)):          
    roi_mask, name = value
    
    fig_1 =plot_pretty_scatter(m1_cc[roi_mask], m2_cc[roi_mask], cc_th, [-.6, .6], [-.25, 0.85])
    plt.xlabel('%s $\leftrightarrow$ %s\n' % (m2_name, m1_name) +r'$\rho_2 - \rho_1$', labelpad=20)
    plt.ylabel('Average accuracy\n'+r'$(\rho_1 + \rho_2)/2$', labelpad=10)      
    plt.text(-0.55, .8, name, horizontalalignment='left', fontsize=18, weight='bold')
    
    filename = output_dir + "%s_vs_%s_%s_%s_nonlinearity" % (m1_name, m2_name, subject, name) + saveext
    fig_1.savefig(filename, **savearg)
    plt.close()

# %% [markdown]
# # (Temporary) Save positioning data

# %%
special_dict = {'%s_voxelROI' % subject: voxelROI,
                '%s_voxelIDX' % subject: voxelIDX,
                '%s_DNN_rf_model' % subject: m1_data_dict['models'],
                '%s_DNN_val_cc' % subject: m1_data_dict['val_cc'],
                '%s_GBR_rf_model' % subject: m2_data_dict['models'],
                '%s_GBR_val_cc' % subject: m2_data_dict['val_cc']
               }

# %%
special_file = open(root_dir + '%s_rf_attributes.pkl' % subject, 'wb')
pickle.dump(special_dict, special_file)
special_file.close()

# %% [markdown]
# # 3) DEEPNET MODEL ANALYSIS

# %%
m_name      = m1_name
m_data_dict = m1_data_dict
m_part_dict = m1_part_dict

# %%
cc_th = 0.27

# %% [markdown]
# ## 3a) Display RF density in visual field (validated voxels only) and size distribution

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
cc_mask = m_data_dict['val_cc']>cc_th
_,_,g_stack = pnu.make_gaussian_stack(m_data_dict['models'][cc_mask,0], m_data_dict['models'][cc_mask,1], m_data_dict['models'][cc_mask,2], 64, size=20., dtype=np.float32)
plt.imshow(np.sum(g_stack, axis=0), cmap='magma', interpolation='None')
plt.grid('off')
plt.title('rf positions')
plt.subplot(1,3,2)
_=plt.hist(m_data_dict['models'][cc_mask,2], bins=50, log=True)
plt.ylim([0.9,1e5])
plt.title('rf size count')

# %%
from scipy.stats import rv_discrete
_pruning_dist = lambda x: rv_discrete(name='custm', values=([0,1], [x, 1-x]))
pruning_dist = _pruning_dist(1.)

# %%
rg = roi_main
nROI = len(rg)
prune_frac = 0.3
pruning_dist = _pruning_dist(prune_frac)

cc_mask = m_data_dict['val_cc']>cc_th
rand_mask = pruning_dist.rvs(size=cc_mask.shape)

smin, smax = np.amin(m_data_dict['models'][:,2])-1.5, np.amax(m_data_dict['models'][:,2])

yROI = nROI // 5
xROI = int(np.ceil(np.float(nROI) / yROI))
print xROI, yROI

fig_3a = plt.figure(figsize=(5*xROI,5*yROI))
for roi, value  in enumerate(iterate_roi(rg, voxelROI.flatten(), roi_names)):          
    roi_mask, name = value
    plt.subplot(yROI,xROI,roi+1)
    plt.subplots_adjust(left=.1, bottom=.1, right=.95, top=.95, wspace=.3, hspace=0.)

    circle_mask = np.logical_and(rand_mask, np.logical_and(roi_mask, cc_mask))
    plot_rf_as_circles(m_data_dict['models'][circle_mask], smin, smax)   
    
    plt.xlim([-10, 10])
    plt.ylim([-10, 10])
    plt.text(-9.5, 8.5, name, horizontalalignment='left', fontsize=18)
# Out:
# 5 1
# (-0.80000001192092896, 8.0)
# (-0.80000001192092896, 8.0)
# (-0.80000001192092896, 8.0)
# (-0.80000001192092896, 8.0)
# (-0.80000001192092896, 8.0)

# %% [markdown]
# ## 3b) Estimate eccentricity and pooling size (if possible)

# %%
nk = np.array([55., 27., 13., 13., 13., 1., 1., 1.]) # number of spatial unit for each layer
Pk = np.array([11./227, 51./227, 99./227, 131./227, 163./227, 1., 1., 1.]) # maximum pooling size
print Pk

ecc = np.sqrt(np.square(m_data_dict['models'][:,0])+np.square(m_data_dict['models'][:,1]))
env  = Pk * 10. # estimate pooling size (in degree)
# Out:
# [ 0.04845815  0.2246696   0.43612335  0.57709251  0.71806167  1.          1.
#   1.        ]

# %% [markdown]
# ## 3c) Display the feature pooling size per ROI as a function of eccentricity

# %%
from scipy.optimize import curve_fit
def pooling_area(x, a, b):
    return a*x**1+b #**(1+b)

rg = roi_main
nROI = len(rg)
cc_mask = m_data_dict['val_cc']>cc_th

delta = 1.
width = 2*delta
span = 8.
fit_up_to = [8, 8, 8, 7, 5]
bins = np.linspace(0, span, int(span/delta)+1)
print bins

center   = np.ndarray(shape=(len(bins)))
avg_size = np.ndarray(shape=(nROI, len(bins)))
std_size = np.ndarray(shape=(nROI, len(bins)))

A = []
plt.figure(figsize=(5*nROI,5)) 
for roi, value  in enumerate(iterate_roi(rg, voxelROI.flatten(), roi_names)):          
    roi_mask, name = value
    for i,d in enumerate(bins):
        center[i] = (2*d+delta) / 2
        mask = np.logical_and(np.logical_and(np.logical_and(ecc>d, ecc<=d+width), roi_mask), cc_mask)
        values = m_data_dict['models'][mask,2]
        
        avg_size[roi, i] = np.mean(values)
        std_size[roi, i] = np.std(values)
    
    plt.subplot(1,nROI,roi+1)
    plt.errorbar(center, avg_size[roi], std_size[roi], marker=roi_markers[roi], markersize=10, linestyle='none')
    
    if(np.isnan(np.sum(avg_size[roi]))==False):
        a = curve_fit(pooling_area, center[:fit_up_to[roi]], avg_size[roi, :fit_up_to[roi]])
        A += [a,]
        pooling_area_fn = np.vectorize(lambda x: pooling_area(x, a[0][0], a[0][1])) 
        plt.plot(center, pooling_area_fn(center), color='r', lw=2)    
        plt.ylim(0.0, 3.0)
    else:
        A += [[[0, 0]],]
    plt.title(name)
# Out:
# [ 0.  1.  2.  3.  4.  5.  6.  7.  8.]
# /usr/local/lib/python2.7/dist-packages/numpy/core/fromnumeric.py:2889: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.py:135: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)

# %%
fig_3c1 = plt.figure(figsize=(8,6))
plt.subplot(111)
plt.subplots_adjust(left=.2, bottom=.2, right=.7, top=.85, wspace=0., hspace=0.)
reg = np.arange(0., 11., .5)

for roi, value  in enumerate(iterate_roi(rg, voxelROI.flatten(), roi_names)):
    roi_mask, name = value
    p = plt.plot(center, avg_size[roi], marker=roi_markers[roi], markersize=10, linestyle='none')
    pooling_area_fn = np.vectorize(lambda x: pooling_area(x, A[roi][0][0], A[roi][0][1]))
    plt.plot(reg, pooling_area_fn(reg), color=p[0].get_color(), lw=4, label=name)  
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Eccentricity (deg)')
plt.ylabel('f.p.f. radius (deg)')
plt.xlim(0,8)
plt.ylim(0.5, 2.5)
# Out:
# (0.5, 2.5)

# %%
filename = output_dir + "%s_summary_frf_size.eps" % m_name
fig_3c1.patch.set_alpha(0.)
fig_3c1.savefig(filename, format='eps', dpi=1000)
plt.close()

# %% [markdown]
# ### Estimate for pRFs

# %%
pRF = np.sqrt(np.square(env[np.argmax(m_part_dict['val_ri'], axis=0).astype(int)])+ np.square(m_data_dict['models'][:,2]))
#pRF = np.sqrt(np.square(np.sum(env[:,np.newaxis] * m_part_dict['val_ri'], axis=0) / m_data_dict['val_cc']) + np.square(m_data_dict['models'][:,2]))

# %%
rg = roi_main
nROI = len(rg)
cc_mask = m_data_dict['val_cc']>cc_th

delta = 1.
width = 4*delta
span = 8.
fit_up_to = [8, 8, 8, 7, 4]
bins = np.linspace(0, span, span/delta+1)
print bins

center   = np.ndarray(shape=(len(bins)))
avg_size = np.ndarray(shape=(nROI, len(bins)))
std_size = np.ndarray(shape=(nROI, len(bins)))

A = []
these_roi_names = []
plt.figure(figsize=(3*nROI,3))
for roi, value  in enumerate(iterate_roi(rg, voxelROI.flatten(), roi_names)):          
    roi_mask, name = value
    these_roi_names += [name,]
    for i,d in enumerate(bins):
        center[i] = (2*d+delta) / 2
        mask = np.logical_and(np.logical_and(np.logical_and(ecc>d, ecc<=d+width), roi_mask), cc_mask)
        values = pRF[mask]
        
        avg_size[roi, i] = np.mean(values)
        std_size[roi, i] = np.std(values)

    plt.subplot(1,nROI,roi+1)
    plt.errorbar(center, avg_size[roi], std_size[roi], marker='o', linestyle='none')        
    if(np.isnan(np.sum(avg_size[roi]))==False):
        a = curve_fit(pooling_area, center[:fit_up_to[roi]], avg_size[roi, :fit_up_to[roi]])
        A += [a,]
        pooling_area_fn = np.vectorize(lambda x: pooling_area(x, a[0][0], a[0][1])) 
        plt.plot(center, pooling_area_fn(center), color='r', lw=2)    
        plt.ylim(0.0, 3.0)
    else:
        A += [[[0, 0]],]

    plt.ylim(0.0, 15.0)
    plt.title(these_roi_names[roi])
# Out:
# [ 0.  1.  2.  3.  4.  5.  6.  7.  8.]
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:9: DeprecationWarning: object of type <type 'float'> cannot be safely interpreted as an integer.

# %%
fig_3c2 = plt.figure(figsize=(8,6))
plt.subplot(111)
plt.subplots_adjust(left=.2, bottom=.2, right=.7, top=.85, wspace=0., hspace=0.)
reg = np.arange(0., 11., .5)

for roi, value  in enumerate(iterate_roi(rg, voxelROI.flatten(), roi_names)):
    roi_mask, name = value
    p = plt.plot(center, avg_size[roi], marker=roi_markers[roi], markersize=10, linestyle='none')
    pooling_area_fn = np.vectorize(lambda x: pooling_area(x, A[roi][0][0], A[roi][0][1]))
    plt.plot(reg, pooling_area_fn(reg), color=p[0].get_color(), lw=4, label=name)  
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Eccentricity (deg)')
plt.ylabel('pRF radius (deg)')
plt.xlim(0,8)
plt.ylim(0., 15)
# Out:
# (0.0, 15)

# %%
filename = output_dir + "%s_summary_prf_size.eps" % m_name
fig_3c2.patch.set_alpha(0.)
fig_3c2.savefig(filename, format='eps', dpi=1000)
plt.close()

# %% [markdown]
# ## 3d) Parameter analysis (What connects where)

# %%
rg = roi_vendrodorsal
nROI = len(rg)
cc_mask = m_data_dict['val_cc']>cc_th

L = m_part_dict['val_ri'].shape[0]
layeridx  = [1, 2, 3, 4, 5, 6, 7, 8]
layername = ['conv1', 'conv2', 'conv3', 'conv4', 'conv5',  'fc6', 'fc7', 'fc8']

partition_R_avg = np.ndarray(shape=(L, nROI), dtype=fpX)
partition_R_std = np.ndarray(shape=(L, nROI), dtype=fpX)
these_roi_names = []
for roi, value  in enumerate(iterate_roi(rg, voxelROI.flatten(), roi_names)):          
    roi_mask, name = value
    mask = np.logical_and(roi_mask, cc_mask)
    #mask = np.logical_and(np.logical_and(roi_mask, cc_mask), ecc>=5.)
    these_roi_names += [name,]
    for l in range(L):
        values = m_part_dict['val_ri'][l, mask] /  m_data_dict['val_cc'][mask]
        partition_R_avg[l,roi] = np.mean(values)
        partition_R_std[l,roi] = np.std(values)

# %%
fig_3d1 = plt.figure(figsize=(10,6))
ax = plt.subplot(111)
plt.subplots_adjust(left=.2, bottom=.2, right=.8, top=.9, wspace=.1, hspace=.1)

vrel = partition_R_avg[0][3] # + vrel - v[3]
for l, v in enumerate(partition_R_avg):
    plt.plot(v[:], label=layername[l], lw=4, marker=roi_markers[l], markersize=10, linestyle='dashed' if l>4 else 'solid')
plt.legend(bbox_to_anchor=(1.01, 1), loc=0, borderaxespad=0)
ax.set_xticklabels(these_roi_names)
plt.xlabel('Ventral $\leftrightarrow$ Dorsal')
plt.ylabel('Contribution to the prediction accuracy')

# %%
filename = output_dir + "%s_layer_ventrodorsal_soft_connections_plot.eps" % m_name
fig_3d1.patch.set_alpha(0.)
fig_3d1.savefig(filename, format='eps', dpi=1000)
plt.close()

# %%
color=iter(cm.magma(np.linspace(0,1,L)))

fig_3d2 = plt.figure(figsize=(10,6))
plt.subplot(111)
plt.subplots_adjust(left=.2, bottom=.2, right=.8, top=.9, wspace=.1, hspace=.1)
c=next(color)
plist = [] #  yerr=partition_R_std[0,:],
_ = plt.bar(np.arange(len(these_roi_names)), partition_R_avg[0,:], color=c, align='center')
plist += [_,]
for l in range(1,L):
    c=next(color)
    _= plt.bar(np.arange(len(these_roi_names)), partition_R_avg[l,:], bottom=np.sum(partition_R_avg[:l,:],axis=0), color=c,\
        align='center', tick_label=these_roi_names)
    plist += [_,]
plt.legend(plist, ['%s' % layername[l] for l in range(len(plist))], bbox_to_anchor=(1.01, 1), loc=0, borderaxespad=0)
plt.ylim([0,1])
plt.xlabel('Ventral $\leftrightarrow$ Dorsal')
plt.ylabel('Layer contribution to prediction accuracy\n (averaged over voxels in ROI)', labelpad=10)

# %%
filename = output_dir + "%s_layer_ventrodorsal_soft_connections_bar.eps" % m_name
fig_3d2.patch.set_alpha(0.)
fig_3d2.savefig(filename, format='eps', dpi=1000)
plt.close()

# %% [markdown]
# ## 3e) Layer tuning

# %%
rg = roi_main #roi_vendrodorsal
nROI = len(rg)
cc_mask = m_data_dict['val_cc']>cc_th

partition_R_avg = np.ndarray(shape=(L, nROI), dtype=fpX)
partition_R_std = np.ndarray(shape=(L, nROI), dtype=fpX)
these_roi_names = []
for roi, value  in enumerate(iterate_roi(rg, voxelROI.flatten(), roi_names)):          
    roi_mask, name = value
    mask = np.logical_and(roi_mask, cc_mask)
    #mask = np.logical_and(np.logical_and(roi_mask, cc_mask), ecc<5.)
    these_roi_names += [name,]
    for l in range(L):
        values = m_part_dict['val_ri'][l, mask] /  m_data_dict['val_cc'][mask]
        partition_R_avg[l,roi] = np.mean(values)
        partition_R_std[l,roi] = np.std(values)

# %%
fig_3e1 = plt.figure(figsize=(8,6))
plt.subplot(111)
plt.subplots_adjust(left=.2, bottom=.2, right=.7, top=.9, wspace=.1, hspace=.1)
for r in range(nROI):
    #plt.plot(freq, partition_R_avg[:,r], lw=4, marker='o', color=next(color), label=these_roi_names[r])
    plt.plot(layeridx, partition_R_avg[:,r], lw=4, marker=roi_markers[r], markersize=10, label=these_roi_names[r])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#plt.xlabel('Spatial frequency')
plt.ylim([0, 0.45])
plt.xlabel('Deepnet layer')
plt.ylabel('Contribution to the total prediction accuracy')

# %%
filename = output_dir + "%s_layer_roi_connections_all.eps" % m_name
fig_3e1.patch.set_alpha(0.)
fig_3e1.savefig(filename, format='eps', dpi=1000)
plt.close()

# %%
rg = roi_main

nROI = len(rg)
L = m_part_dict['val_ri'].shape[0]

partition_R_avg = np.ndarray(shape=(L, nROI), dtype=fpX)
partition_R_std = np.ndarray(shape=(L, nROI), dtype=fpX)

fig_3e2 = plt.figure(figsize=(16,6))
for i,f in enumerate([ecc<5., ecc>=5.]):
    these_roi_names = []
    for roi, value  in enumerate(iterate_roi(rg, voxelROI.flatten(), roi_names)):          
        roi_mask, name = value
        mask = np.logical_and(np.logical_and(roi_mask, m_data_dict['val_cc']>cc_th), f)
        these_roi_names += [name,]
        for l in range(L):
            values = m_part_dict['val_ri'][l, mask] /  m_data_dict['val_cc'][mask]
            partition_R_avg[l,roi] = np.mean(values)
            partition_R_std[l,roi] = np.std(values)        
    #these_roi_names[2] = 'V3 a/b'
    
    plt.subplot(1,2,i+1)
    #plt.subplots_adjust(left=0., bottom=.2, right=.7, top=.85, wspace=0.2, hspace=0.)
    plt.subplots_adjust(left=.2, bottom=.2, right=.7, top=.9, wspace=.2, hspace=.1)
    for r in range(nROI):
        plt.plot(layeridx, partition_R_avg[:,r], lw=4, marker=roi_markers[r], markersize=10, label=these_roi_names[r])
    
    plt.xlabel('Spatial frequency (1/deg)')
    plt.ylim([0.0, .45])
    if i==1:      
        plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
        plt.text(1.3, 0.41, 'Ecc.>=5.0', horizontalalignment='left', fontsize=18)
    else:
        plt.ylabel('Contribution to the total prediction accuracy')
        plt.text(1.3, 0.41, 'Ecc.<5.0', horizontalalignment='left', fontsize=18)

# %%
filename = output_dir + "%s_layer_roi_connections_eccentricity_separation.eps" % m_name
fig_3e2.patch.set_alpha(0.)
fig_3e2.savefig(filename, format='eps', dpi=1000)
plt.close()

# %% [markdown]
# # 4) GABOR MODEL ANALYSIS

# %%
m_name      = m2_name
m_data_dict = m2_data_dict
m_part_dict = m2_part_dict

# %% [markdown]
# ## 4a) Display RF density in visual field (validated voxels only) and size distribution

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
cc_mask = m_data_dict['val_cc']>cc_th
_,_,g_stack = pnu.make_gaussian_stack(m_data_dict['models'][cc_mask,0], m_data_dict['models'][cc_mask,1], m_data_dict['models'][cc_mask,2], 64, size=20., dtype=np.float32)
plt.imshow(np.sum(g_stack, axis=0), cmap='magma', interpolation='None')
plt.grid('off')
plt.title('rf positions')
plt.subplot(1,3,2)
_=plt.hist(m_data_dict['models'][cc_mask,2], bins=50, log=True)
plt.ylim([0.9,1e5])
plt.title('rf size count')

# %%
import matplotlib.colors as colors
import matplotlib.cm as cmx

def plot_rf_as_circles(rfs, smin, smax):
    cNorm  = colors.Normalize(vmin=smin, vmax=smax)
    scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=plt.get_cmap('cubehelix_r') )
    print scalarMap.get_clim()
    for rf in rfs:
        colorVal = scalarMap.to_rgba(rf[2])
        c = plt.Circle((rf[0], rf[1]), rf[2], color=colorVal, fill=False, lw=0.7)
        plt.gca().add_artist(c)
    plt.xlim([-15,15])
    plt.ylim([-15,15])
    plt.xlabel('x (degree)')
    plt.ylabel('y (degree)', labelpad=0)
    plt.gca().set_aspect('equal')
    
from scipy.stats import rv_discrete
_pruning_dist = lambda x: rv_discrete(name='custm', values=([0,1], [x, 1-x]))
pruning_dist = _pruning_dist(1.)

# %%
rg = roi_main
nROI = len(rg)
prune_frac = 0.3
pruning_dist = _pruning_dist(prune_frac)

cc_mask = m_data_dict['val_cc']>0.2
rand_mask = pruning_dist.rvs(size=cc_mask.shape)

smin, smax = np.amin(m_data_dict['models'][:,2])-1.5, np.amax(m_data_dict['models'][:,2])

yROI = nROI // 5
xROI = int(np.ceil(np.float(nROI) / yROI))
print xROI, yROI

fig_3a = plt.figure(figsize=(5*xROI,5*yROI))
for roi, value  in enumerate(iterate_roi(rg, voxelROI.flatten(), roi_names)):          
    roi_mask, name = value
    plt.subplot(yROI,xROI,roi+1)
    plt.subplots_adjust(left=.1, bottom=.1, right=.95, top=.95, wspace=.3, hspace=0.)

    circle_mask = np.logical_and(rand_mask, np.logical_and(roi_mask, cc_mask))
    plot_rf_as_circles(m_data_dict['models'][circle_mask], smin, smax)   
    
    plt.xlim([-10, 10])
    plt.ylim([-10, 10])
    plt.text(-9.5, 8.5, name, horizontalalignment='left', fontsize=18)
# Out:
# 5 1
# (-1.0, 8.0)
# (-1.0, 8.0)
# (-1.0, 8.0)
# (-1.0, 8.0)
# (-1.0, 8.0)

# %% [markdown]
# ## 4b) Estimate eccentricity and pooling size (if possible)

# %%
ecc = np.sqrt(np.square(m_data_dict['models'][:,0])+np.square(m_data_dict['models'][:,1]))
env = 1. / np.logspace(np.log10(0.25),np.log10(6), 12)
freq = prf.logspace(12)(.25, 6)

print env
# Out:
# [ 4.          2.99630654  2.24446322  1.68127496  1.25940379  0.94338995
#   0.70667137  0.52935101  0.39652447  0.29702722  0.22249615  0.16666667]

# %% [markdown]
# ## 4c) Display the feature pooling size per ROI as a function of eccentricity

# %%
from scipy.optimize import curve_fit
def pooling_area(x, a, b):
    return a*x**1+b #**(1+b)

rg = roi_main
nROI = len(rg)
cc_mask = m_data_dict['val_cc']>cc_th

delta = 1.
width = 1.5*delta
span = 8.
fit_up_to = [8, 8, 8, 7, 6]
bins = np.linspace(0, span, int(span/delta)+1)
print bins

center   = np.ndarray(shape=(len(bins)))
avg_size = np.ndarray(shape=(nROI, len(bins)))
std_size = np.ndarray(shape=(nROI, len(bins)))

A = []
plt.figure(figsize=(5*nROI,5)) 
for roi, value  in enumerate(iterate_roi(rg, voxelROI.flatten(), roi_names)):          
    roi_mask, name = value
    for i,d in enumerate(bins):
        center[i] = (2*d+delta) / 2
        mask = np.logical_and(np.logical_and(np.logical_and(ecc>d, ecc<=d+width), roi_mask), cc_mask)
        values = m_data_dict['models'][mask,2]
        
        avg_size[roi, i] = np.mean(values)
        std_size[roi, i] = np.std(values)
    
    plt.subplot(1,nROI,roi+1)
    plt.errorbar(center, avg_size[roi], std_size[roi], marker=roi_markers[roi], markersize=10, linestyle='none')
    
    if(np.isnan(np.sum(avg_size[roi, :fit_up_to[roi]]))==False):
        a = curve_fit(pooling_area, center[:fit_up_to[roi]], avg_size[roi, :fit_up_to[roi]])
        A += [a,]
        pooling_area_fn = np.vectorize(lambda x: pooling_area(x, a[0][0], a[0][1])) 
        plt.plot(center, pooling_area_fn(center), color='r', lw=2)    
        plt.ylim(0.0, 3.0)
    else:
        A += [[[0, 0]],]
    plt.title(name)
# Out:
# [ 0.  1.  2.  3.  4.  5.  6.  7.  8.]

# %%
fig_4c1 = plt.figure(figsize=(8,6))
plt.subplot(111)
plt.subplots_adjust(left=.2, bottom=.2, right=.7, top=.85, wspace=0., hspace=0.)
reg = np.arange(0., 11., .5)

for roi, value  in enumerate(iterate_roi(rg, voxelROI.flatten(), roi_names)):
    roi_mask, name = value
    p = plt.plot(center, avg_size[roi], marker=roi_markers[roi], markersize=10, linestyle='none')
    pooling_area_fn = np.vectorize(lambda x: pooling_area(x, A[roi][0][0], A[roi][0][1]))
    plt.plot(reg, pooling_area_fn(reg), color=p[0].get_color(), lw=4, label=name)  
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Eccentricity (deg)')
plt.ylabel('f.p.f. radius (deg)')
plt.xlim(0,8)
plt.ylim(0.5, 2.5)
# Out:
# (0.5, 2.5)

# %%
***
filename = output_dir + "%s_summary_frf_size.eps" % m_name
fig_4c1.patch.set_alpha(0.)
fig_4c1.savefig(filename, format='eps', dpi=1000)
plt.close()

# %% [markdown]
# ### Estimate for pRFs

# %%
pRF = np.sqrt(np.square(env[np.argmax(m_part_dict['val_ri'], axis=0).astype(int)])+ np.square(m_data_dict['models'][:,2]))
#pRF = np.sqrt(np.square(np.sum(env[:,np.newaxis] * m_part_dict['val_ri'], axis=0) / m_data_dict['val_cc']) + np.square(m_data_dict['models'][:,2]))

# %%
rg = roi_main
nROI = len(rg)
cc_mask = m_data_dict['val_cc']>cc_th

delta = 1.
width = 1.5*delta
span = 8.
fit_up_to = [8, 8, 8, 7, 6]
bins = np.linspace(0, span, int(span/delta)+1)
print bins

center   = np.ndarray(shape=(len(bins)))
avg_size = np.ndarray(shape=(nROI, len(bins)))
std_size = np.ndarray(shape=(nROI, len(bins)))

A = []
these_roi_names = []
plt.figure(figsize=(3*nROI,3))
for roi, value  in enumerate(iterate_roi(rg, voxelROI.flatten(), roi_names)):          
    roi_mask, name = value
    these_roi_names += [name,]
    for i,d in enumerate(bins):
        center[i] = (2*d+delta) / 2
        mask = np.logical_and(np.logical_and(np.logical_and(ecc>d, ecc<=d+width), roi_mask), cc_mask)
        values = pRF[mask]
        
        avg_size[roi, i] = np.mean(values)
        std_size[roi, i] = np.std(values)

    plt.subplot(1,nROI,roi+1)
    plt.errorbar(center, avg_size[roi], std_size[roi], marker='o', linestyle='none')        
    if(np.isnan(np.sum(avg_size[roi, fit_up_to[roi]]))==False):
        a = curve_fit(pooling_area, center[:fit_up_to[roi]], avg_size[roi, :fit_up_to[roi]])
        A += [a,]
        pooling_area_fn = np.vectorize(lambda x: pooling_area(x, a[0][0], a[0][1])) 
        plt.plot(center, pooling_area_fn(center), color='r', lw=2)    
        plt.ylim(0.0, 3.0)
    else:
        A += [[[0, 0]],]

    plt.ylim(0.0, 4.0)
    plt.title(these_roi_names[roi])
# Out:
# [ 0.  1.  2.  3.  4.  5.  6.  7.  8.]

# %%
fig_4c2 = plt.figure(figsize=(8,6))
plt.subplot(111)
plt.subplots_adjust(left=.2, bottom=.2, right=.7, top=.85, wspace=0., hspace=0.)
reg = np.arange(0., 11., .5)

for roi, value  in enumerate(iterate_roi(rg, voxelROI.flatten(), roi_names)):
    roi_mask, name = value
    p = plt.plot(center, avg_size[roi], marker=roi_markers[roi], markersize=10, linestyle='none')
    pooling_area_fn = np.vectorize(lambda x: pooling_area(x, A[roi][0][0], A[roi][0][1]))
    plt.plot(reg, pooling_area_fn(reg), color=p[0].get_color(), lw=4, label=name)  
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Eccentricity (deg)')
plt.ylabel('pRF radius (deg)')
plt.xlim(0,8)
plt.ylim(0., 4)
# Out:
# (0.0, 4)

# %%
filename = output_dir + "%s_summary_prf_size.eps" % m_name
fig_4c2.patch.set_alpha(0.)
fig_4c2.savefig(filename, format='eps', dpi=1000)
plt.close()

# %% [markdown]
# ## 4d) Parameter analysis (Frequency tuning)

# %%
rg = roi_main
nROI = len(rg)

L = m_part_dict['val_ri'].shape[0]
layername = freq

partition_R_avg = np.ndarray(shape=(L, nROI), dtype=fpX)
partition_R_std = np.ndarray(shape=(L, nROI), dtype=fpX)
these_roi_names = []
for roi, value  in enumerate(iterate_roi(rg, voxelROI.flatten(), roi_names)):          
    roi_mask, name = value
    mask = np.logical_and(roi_mask, m_data_dict['val_cc']>cc_th)
    #mask = np.logical_and(np.logical_and(roi_mask, m_data_dict['val_cc']>0.3), ecc<5.)
    these_roi_names += [name,]
    for l in range(L):
        values = m_part_dict['val_ri'][l, mask] /  m_data_dict['val_cc'][mask]
        partition_R_avg[l,roi] = np.mean(values)
        partition_R_std[l,roi] = np.std(values)        
#these_roi_names[2] = 'V3 a/b'

# %%
fig_4d1 = plt.figure(figsize=(8,6))
plt.subplot(111)
plt.subplots_adjust(left=.2, bottom=.2, right=.7, top=.85, wspace=0., hspace=0.)

for r in range(nROI):
    plt.plot(freq, partition_R_avg[:,r], lw=4, marker=roi_markers[r], markersize=10, label=these_roi_names[r])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Spatial frequency (1/deg)')
plt.xscale('log')
#plt.xlim([0.1, 10])
plt.ylabel('Contribution to the total prediction accuracy')

# %%
filename = output_dir + "%s_layer_frequency_tuning_plot_all.eps" % m_name
fig_4d1.patch.set_alpha(0.)
fig_4d1.savefig(filename, format='eps', dpi=1000)
plt.close()

# %%
rg = roi_main
nROI = len(rg)

L = m_part_dict['val_ri'].shape[0]
layername = freq

partition_R_avg = np.ndarray(shape=(L, nROI), dtype=fpX)
partition_R_std = np.ndarray(shape=(L, nROI), dtype=fpX)

fig_4d2 = plt.figure(figsize=(16,6))
for i,f in enumerate([ecc<5., ecc>=5.]):
    these_roi_names = []
    for roi, value  in enumerate(iterate_roi(rg, voxelROI.flatten(), roi_names)):          
        roi_mask, name = value
        mask = np.logical_and(np.logical_and(roi_mask, m_data_dict['val_cc']>cc_th), f)
        these_roi_names += [name,]
        for l in range(L):
            values = m_part_dict['val_ri'][l, mask] /  m_data_dict['val_cc'][mask]
            partition_R_avg[l,roi] = np.mean(values)
            partition_R_std[l,roi] = np.std(values)        
    #these_roi_names[2] = 'V3 a/b'
    
    plt.subplot(1,2,i+1)
    #plt.subplots_adjust(left=0., bottom=.2, right=.7, top=.85, wspace=0.2, hspace=0.)
    plt.subplots_adjust(left=.2, bottom=.2, right=.7, top=.9, wspace=.2, hspace=.1)
    for r in range(nROI):
        plt.plot(freq, partition_R_avg[:,r], lw=4, marker=roi_markers[r], markersize=10, label=these_roi_names[r])
    
    plt.xlabel('Spatial frequency (1/deg)')
    plt.xscale('log')
    #plt.xlim([0.1, 10])
    plt.ylim([0.0, .20])
    if i==1:      
        plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
        plt.text(0.12, 0.18, 'Ecc.>=5.0', horizontalalignment='left', fontsize=18)
    else:
        plt.ylabel('Contribution to the total prediction accuracy')
        plt.text(0.12, 0.18, 'Ecc.<5.0', horizontalalignment='left', fontsize=18)

# %%
filename = output_dir + "%s_layer_frequency_tuning_plot_eccentricity_separation.eps" % m_name
fig_4d2.patch.set_alpha(0.)
fig_4d2.savefig(filename, format='eps', dpi=1000)
plt.close()
